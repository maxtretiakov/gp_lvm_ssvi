# %%
import math, torch, tqdm, matplotlib.pyplot as plt
from dataclasses import dataclass, field
from typing import Callable, Optional

torch.set_default_dtype(torch.float64)
plt.rcParams["figure.autolayout"] = True

# ─────────────── Helpers ───────────────

def _device() -> str:
    return "cuda" if torch.cuda.is_available() else "cpu"

def _rho(t: int, t0: float, kappa: float) -> float:
    return (t0 + t) ** (-kappa)

def init_circle(Y: torch.Tensor, Q: int) -> torch.Tensor:
    theta = torch.linspace(0, 2 * math.pi, Y.size(0) + 1, device=Y.device)[:-1]
    return torch.stack([torch.sin(theta), torch.cos(theta)], 1)[:, :Q]

def default_grid_Z(Y: torch.Tensor, Q: int, M: int) -> torch.Tensor:
    side = round(M ** (1 / Q))
    g = torch.linspace(-1.5, 1.5, side, device=Y.device)
    mesh = torch.meshgrid(*[g]*Q, indexing="ij")
    return torch.stack(mesh, -1).reshape(-1, Q)[:M]

def generate_ring_data(N: int = 400, noise: float = 0.05, device="cpu") -> torch.Tensor:
    theta = torch.linspace(0, 2 * math.pi, N + 1, device=device)[:-1]
    r = 1.0 + noise * torch.randn(N, device=device)
    return torch.stack([r * torch.sin(theta), r * torch.cos(theta)], 1)

# ─────────────── Config ───────────────

@dataclass
class GPLVMConfig:
    latent_dim: int = 2
    inducing_grid: int = 8
    lr_inner: float = 1e-2
    lr_hyp: float = 2e-4
    robbins_t0: float = 50.0
    robbins_kappa: float = 0.9
    prior_x_var: float = 5.0
    init_mu: Callable[[torch.Tensor, int], torch.Tensor] = init_circle
    init_Z: Optional[Callable[[torch.Tensor, int, int], torch.Tensor]] = None
    init_log_s2x: float = -2.0
    init_log_sf2: float = 0.0
    init_log_beta_inv: float = -3.0
    init_log_alpha: Optional[torch.Tensor] = None
    plot_latents_fn: Optional[Callable[["GPLVM_SSVI"], None]] = None
    device: str = field(default_factory=_device)

# ─────────────── Model ───────────────

class GPLVM_SSVI:
    def __init__(self, Y: torch.Tensor, cfg: GPLVMConfig):
        self.cfg = cfg
        self.Y = Y.to(cfg.device)
        self.N, self.D = Y.shape
        self.Q = cfg.latent_dim
        self.dev = cfg.device

        self.M = cfg.inducing_grid ** self.Q
        if cfg.init_Z is not None:
            self.Z = cfg.init_Z(self.Y, self.Q, self.M)
        else:
            self.Z = default_grid_Z(self.Y, self.Q, self.M)

        self.log_sf2 = torch.tensor(cfg.init_log_sf2, device=self.dev, requires_grad=True)
        self.log_beta_inv = torch.tensor(cfg.init_log_beta_inv, device=self.dev, requires_grad=True)
        self.log_alpha = (
            cfg.init_log_alpha.to(self.dev).requires_grad_()
            if cfg.init_log_alpha is not None
            else torch.zeros(self.Q, device=self.dev, requires_grad=True)
        )
        self.opt_hyp = torch.optim.Adam([self.log_sf2, self.log_alpha, self.log_beta_inv], lr=cfg.lr_hyp)

        with torch.no_grad():
            s2_u = torch.full((self.D, self.M), 1e-2, device=self.dev)
            self.h_u = torch.zeros_like(s2_u)
            self.lam_u = -0.5 / s2_u
        self.h_u.requires_grad_(False)
        self.lam_u.requires_grad_(False)

        self.mu_x = cfg.init_mu(self.Y, self.Q).detach().requires_grad_()
        self.log_s2x = torch.full_like(self.mu_x, cfg.init_log_s2x, requires_grad=True)
        self.opt_loc = torch.optim.Adam([self.mu_x, self.log_s2x], lr=cfg.lr_inner)

        self.e_it, self.e_val = [], []

    def _k(self, x, z):
        a = self.log_alpha.exp()
        return self.log_sf2.exp() * torch.exp(-0.5 * ((x.unsqueeze(-2) - z)**2 * a).sum(-1))

    def _Kmm(self):
        return self._k(self.Z, self.Z) + 1e-6 * torch.eye(self.M, device=self.dev)

    def _noise_var(self):
        return self.log_beta_inv.exp()

    def _psi(self, mu, s2):
        sf2, a = self.log_sf2.exp(), self.log_alpha.exp()
        S = mu.size(0)

        psi0 = sf2.expand(S)
        d1 = a * s2 + 1.0
        c1 = d1.rsqrt().prod(-1, keepdim=True)
        psi1 = sf2 * c1 * torch.exp(
            -0.5 * ((a * (mu[:, None, :] - self.Z) ** 2) / d1[:, None, :]).sum(-1)
        )

        d2 = a * s2 + 2.0
        c2 = d2.rsqrt().prod(-1, keepdim=True)
        ZZ = self.Z[:, None, :] - self.Z[None, :, :]
        dist = (a * ZZ ** 2).sum(-1)
        mid = (self.Z[:, None, :] + self.Z[None, :, :]) / 2.0
        mu_c = (mu[:, None, None, :] - mid) ** 2
        expo = torch.exp(-0.25 * dist - 0.5 * ((a * mu_c) / d2[:, None, None, :]).sum(-1))
        psi2 = sf2 ** 2 * c2.unsqueeze(-1) * expo
        return psi0, psi1, psi2

    def _local(self, idx, U, mu_loc, log_s2_loc):
        Km = self._Kmm()
        Lm = torch.linalg.cholesky(Km)
        mu, s2 = mu_loc[idx], log_s2_loc[idx].exp()
        psi0, psi1, psi2 = self._psi(mu, s2)

        A = torch.cholesky_solve(psi1.T, Lm).T
        fmu = A @ U.T
        tr = torch.cholesky_solve(psi2, Lm).diagonal(0, -2, -1).sum(-1)
        sigma2 = (self._noise_var() + psi0 - tr).clamp_min(1e-8)
        log_like = (-0.5 * math.log(2 * math.pi)
                    - 0.5 * sigma2.log()[:, None]
                    - 0.5 * (self.Y[idx] - fmu) ** 2 / sigma2[:, None]).sum(-1)

        kl_x = 0.5 * ((s2 + mu ** 2) / self.cfg.prior_x_var
                     - s2.log() + math.log(self.cfg.prior_x_var) - 1).sum(-1)
        return (log_like - kl_x).mean(), (psi1, psi2, sigma2)

    def _KL_U(self):
        Km = self._Kmm()
        Lm = torch.linalg.cholesky(Km)
        Kin_diag = torch.cholesky_solve(torch.eye(self.M, device=self.dev), Lm).diag()
        var_u = -0.5 / self.lam_u
        mean_u = self.h_u * var_u
        tr = (Kin_diag * var_u).sum()
        quad = (Kin_diag * mean_u ** 2).sum()
        logdet_p = self.D * 2 * Lm.diagonal().log().sum()
        logdet_q = var_u.log().sum()
        return 0.5 * (tr + quad - self.D * self.M + logdet_p - logdet_q)

    def _sample_U(self):
        eps = torch.randn_like(self.h_u)
        var = -0.5 / self.lam_u
        return self.h_u * var + eps * torch.sqrt(var)

    @torch.no_grad()
    def _full_elbo(self):
        l, _ = self._local(torch.arange(self.N, device=self.dev), self._sample_U(), self.mu_x, self.log_s2x)
        return l - self._KL_U()

    def fit(self, num_iters=300, batch_size=128, inner=6, warmup=50):
        bar = tqdm.trange(1, num_iters + 1, ncols=120)
        for t in bar:
            idx = torch.randint(0, self.N, (batch_size,), device=self.dev)

            for _ in range(inner):
                self.opt_loc.zero_grad(set_to_none=True)
                le, _ = self._local(idx, self._sample_U().detach(), self.mu_x, self.log_s2x)
                (-le).backward()
                self.opt_loc.step()
                self.mu_x.detach_().requires_grad_()
                self.log_s2x.detach_().requires_grad_()

            U_s = self._sample_U()
            le, (psi1, _, sigma2) = self._local(idx, U_s, self.mu_x, self.log_s2x)
            if t >= warmup:
                self.opt_hyp.zero_grad(set_to_none=True)
                (-(le - self._KL_U())).backward()
                self.opt_hyp.step()

            rho_t = _rho(t, self.cfg.robbins_t0, self.cfg.robbins_kappa)
            with torch.no_grad():
                Km = self._Kmm()
                Lm = torch.linalg.cholesky(Km)
                A = torch.cholesky_solve(psi1.detach().T, Lm).T
                r_n = ((self.Y[idx] / sigma2[:, None])[:, :, None]) * A[:, None, :]
                q_n = -0.5 * (A ** 2) / sigma2[:, None]
                r_t = r_n.sum(0)
                q_t = q_n.sum(0).unsqueeze(0).expand(self.D, -1)
                deltaU = U_s - self.h_u * (-0.5 / self.lam_u)
                r_t += 2 * q_t * deltaU
                scale = self.N / batch_size
                lambda0 = -0.5 * torch.cholesky_solve(torch.eye(self.M, device=self.dev), Lm).diag()
                self.h_u += rho_t * (scale * r_t - self.h_u)
                self.lam_u += rho_t * (lambda0.unsqueeze(0) + scale * q_t - self.lam_u)
                self.lam_u.clamp_(max=-1e-8)

            if t % 50 == 0:
                e = self._full_elbo().item()
                self.e_it.append(t)
                self.e_val.append(e)
                bar.set_postfix({"ELBO": f"{e:.2e}"})
        return self

    def plot_elbo(self):
        plt.figure(figsize=(4, 3))
        plt.plot(self.e_it, self.e_val, "-o")
        plt.xlabel("iteration")
        plt.ylabel("ELBO")
        plt.title("ELBO trajectory")
        plt.grid(ls=":")
        plt.show()

    def plot_latents(self):
        if self.cfg.plot_latents_fn is not None:
            return self.cfg.plot_latents_fn(self)

        if self.Q != 2:
            print("Latent scatter only for Q=2")
            return
        with torch.no_grad():
            plt.figure(figsize=(4, 4))
            plt.scatter(
                self.mu_x[:, 0].cpu(),
                self.mu_x[:, 1].cpu(),
                c=self.Y[:, 0].cpu(),
                cmap="viridis",
                s=12,
            )
            plt.gca().set_aspect("equal")
            plt.xlabel(r"$\mu_1$")
            plt.ylabel(r"$\mu_2$")
            plt.title("latent 2-D space (colour = $y_1$)")
            plt.colorbar(label="$y_1$")
            plt.show()

# ─────────────── Run on Ring ───────────────

if __name__ == "__main__":
    torch.manual_seed(0)
    Y = generate_ring_data()

    cfg = GPLVMConfig(
        latent_dim=2,
        inducing_grid=8,
        init_mu=init_circle,
        init_Z=None,                  # use default grid
        plot_latents_fn=None,         # default color by y₁
        device="cpu"
    )

    model = GPLVM_SSVI(Y, cfg).fit(num_iters=300, batch_size=128)
    model.plot_elbo()
    model.plot_latents()
# Out:
#   4%|███                                                                               | 11/300 [00:07<03:24,  1.41it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_44140\2566630998.py in <module>
#     249     )
#     250
# --> 251     model = GPLVM_SSVI(Y, cfg).fit(num_iters=300, batch_size=128)
#     252     model.plot_elbo()
#     253     model.plot_latents()
#
# ~\AppData\Local\Temp\ipykernel_44140\2566630998.py in fit(self, num_iters, batch_size, inner, warmup)
#     166                 self.opt_loc.zero_grad(set_to_none=True)
#     167                 le, _ = self._local(idx, self._sample_U().detach(), self.mu_x, self.log_s2x)
# --> 168                 (-le).backward()
#     169                 self.opt_loc.step()
#     170                 self.mu_x.detach_().requires_grad_()
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     523                 inputs=inputs,
#     524             )
# --> 525         torch.autograd.backward(
#     526             self, gradient, retain_graph, create_graph, inputs=inputs
#     527         )
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     265     # some Python versions print out the first line of a multi-line function
#     266     # calls in the traceback and some print out the last line
# --> 267     _engine_run_backward(
#     268         tensors,
#     269         grad_tensors_,
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\autograd\graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     742         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743     try:
# --> 744         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745             t_outputs, *args, **kwargs
#     746         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
if __name__ == "__main__":
    import urllib.request, tarfile, numpy as np
    from sklearn.decomposition import PCA
    from sklearn.cluster import KMeans
    import matplotlib.pyplot as plt

    # Download oilflow dataset
    url = "http://staffwww.dcs.shef.ac.uk/people/N.Lawrence/resources/3PhData.tar.gz"
    urllib.request.urlretrieve(url, "3PhData.tar.gz")
    with tarfile.open("3PhData.tar.gz", "r:gz") as f:
        f.extract("DataTrn.txt")
        f.extract("DataTrnLbls.txt")

    # Load data
    Y_np = np.loadtxt("DataTrn.txt")
    labels_np = np.loadtxt("DataTrnLbls.txt")
    Y = torch.tensor(Y_np, dtype=torch.float64)
    labels = torch.tensor((labels_np @ np.array([1, 2, 3])).astype(int))

    # Latent init: normalized PCA
    def init_mu_oilflow(Y: torch.Tensor, Q: int) -> torch.Tensor:
        Z = PCA(n_components=Q).fit_transform(Y.cpu().numpy())
        Z = (Z - Z.mean(0)) / Z.std(0)
        return torch.tensor(Z, device=Y.device)

    # Inducing points: KMeans on PCA
    def init_Z_kmeans(Y: torch.Tensor, Q: int, M: int) -> torch.Tensor:
        Z_pca = PCA(n_components=Q).fit_transform(Y.cpu().numpy())
        km = KMeans(n_clusters=M, random_state=0).fit(Z_pca)
        return torch.tensor(km.cluster_centers_, device=Y.device)

    # Latent plot: color by class
    def plot_latents_fn_oilflow(model: GPLVM_SSVI):
        if model.Q != 2:
            print("Only implemented for Q=2")
            return
        with torch.no_grad():
            mu = model.mu_x.cpu().numpy()
            y = labels.cpu().numpy()
            plt.figure(figsize=(5, 5))
            colors = ["blue", "red", "green"]
            for k in [1, 2, 3]:
                mask = y == k
                plt.scatter(mu[mask, 0], mu[mask, 1],
                            s=10, color=colors[k-1], label=f"Class {k}")
            plt.xlabel("Latent dim 1")
            plt.ylabel("Latent dim 2")
            plt.title("2D latent subspace corresponding to 3 phase oilflow")
            plt.legend()
            plt.grid(ls=":")
            plt.gca().set_aspect("equal")
            plt.tight_layout()
            plt.show()

    # Train
    torch.manual_seed(0)
    cfg = GPLVMConfig(
        latent_dim=2,
        inducing_grid=8,  # M = 64
        init_mu=init_mu_oilflow,
        init_Z=init_Z_kmeans,
        plot_latents_fn=plot_latents_fn_oilflow,
        init_log_sf2=1.0,
        init_log_beta_inv=0.0,
        device="cpu",
    )

    model = GPLVM_SSVI(Y, cfg).fit(num_iters=1000, batch_size=128)
    model.plot_elbo()
    model.plot_latents()
# Out:
# 100%|███████████████████████████████████████████████████████████████| 1000/1000 [11:15<00:00,  1.48it/s, ELBO=-5.37e+08]
